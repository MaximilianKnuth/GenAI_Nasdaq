# %%
import pandas as pd

# %%
efr_df = pd.read_csv('EFR.csv')
efr_df.head()
# Out:
#          date       name ticker     cusip  eqr  eqr_expanded  svr  \
# 0  2016-02-26  APPLE INC   AAPL  37833100    5            81    5
# 1  2016-02-19  APPLE INC   AAPL  37833100    5            89    5
# 2  2016-02-12  APPLE INC   AAPL  37833100    5            89    5
# 3  2016-02-05  APPLE INC   AAPL  37833100    5            89    5
# 4  2016-01-29  APPLE INC   AAPL  37833100    5            89    5
#
#    svr_expanded  amr  amr_expanded  sgr  sgr_expanded  gqr  gqr_expanded
# 0            93    5            95    5            87   10            83
# 1            94    5            94    5            89   10            85
# 2            91    5            93    5            91   10            85
# 3            93    5            94    5            94   10            83
# 4            91    5            84    5            85   10            83

# %%
eqr_df = pd.read_csv('EQR.csv')
eqr_df.head()
# Out:
#          date        name ticker latestquarter  eqr  eqrexpanded
# 0  2016-01-01  Apple Inc.   AAPL    2015-09-26    4           68
# 1  2016-01-08  Apple Inc.   AAPL    2015-09-26    4           66
# 2  2016-01-15  Apple Inc.   AAPL    2015-09-26    4           66
# 3  2016-01-22  Apple Inc.   AAPL    2015-09-26    4           69
# 4  2016-01-29  Apple Inc.   AAPL    2015-12-26    5           91

# %%
skms_df = pd.read_csv('SKMS.csv')
skms_df.head()
# Out:
#          date           company  ticker   brand    sales status  \
# 0  2019-01-01        AK S&D inc     NaN     AK몰   192000      F
# 1  2019-01-01       Antz Co Ltd     NaN      앙츠        0      F
# 2  2019-01-01   Asiana Airlines  020560  아시아나항공  1479000      F
# 3  2019-01-01   BKR CORPORATION     NaN     버거킹  1062000      F
# 4  2019-01-01  BLACK YAK CO LTD     NaN    블랙야크   520000      F
#
#                    updated
# 0  2022-12-20 14:43:32.000
# 1  2022-12-20 14:43:32.000
# 2  2022-12-20 14:43:32.000
# 3  2022-12-20 14:43:32.000
# 4  2022-12-20 14:43:32.000
